# %%
import pandas as pd
# %matplotlib inline
from statsmodels.tsa.filters.hp_filter import hpfilter
df = pd.read_excel(r'\Data\India Exchange Rate Dataset.xls',
index_col=0,parse_dates=True)
EXINUS_cycle,EXINUS_trend = hpfilter(df['EXINUS'], lamb=1600)
df['cycle'] =EXINUS_cycle
df['trend'] = EXINUS_trend
df[['trend']].plot(figsize=(15,6)).autoscale(axis='x',tight=True)
